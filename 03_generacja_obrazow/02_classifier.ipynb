# %%
# %load_ext autoreload
# %autoreload 2
from src.experiment import OriginalTrainFakeTest, FakeTrainOriginalTest, MixTrainMixTest
from src.utils import plot_experiment

# %%
experiments_config = {
    "batch_size": 64,
    "learning_rate": 1e-4,
    "device": "cuda",
    "epochs": 20,
    "results_dir": "results",
    "real_data_dir": "data",
    "fake_data_dir": "generated_data",
    "sample_sizes": {"train": 512, "val": 64, "test": 128}
}

# %%
experiment = OriginalTrainFakeTest(
    dataset_name="BloodMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/OriginalTrainFakeTest_BloodMNIST.json
# Experiment Summary: Classifier trained on original data, tested on generated data
# Dataset: BloodMNIST
# Test Results:
#     loss: 1.075479655410163
#     accuracy: 0.7587890625
#     precision: 0.8187909722328186
#     f1_score: 0.7535687685012817
#     recall: 0.7587890625

# %%
experiment = OriginalTrainFakeTest(
    dataset_name="DermaMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/OriginalTrainFakeTest_DermaMNIST.json
# Experiment Summary: Classifier trained on original data, tested on generated data
# Dataset: DermaMNIST
# Test Results:
#     loss: 4.023386810507093
#     accuracy: 0.2477678507566452
#     precision: 0.3871227204799652
#     f1_score: 0.2308131754398346
#     recall: 0.2477678507566452

# %%
experiment = FakeTrainOriginalTest(
    dataset_name="BloodMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/FakeTrainOriginalTest_BloodMNIST.json
# Experiment Summary: Classifier trained on generated data, tested on original data
# Dataset: BloodMNIST
# Test Results:
#     loss: 0.41343637393947574
#     accuracy: 0.890625
#     precision: 0.8988806009292603
#     f1_score: 0.8884350061416626
#     recall: 0.890625

# %%
experiment = FakeTrainOriginalTest(
    dataset_name="DermaMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/FakeTrainOriginalTest_DermaMNIST.json
# Experiment Summary: Classifier trained on generated data, tested on original data
# Dataset: DermaMNIST
# Test Results:
#     loss: 2.7433799441371645
#     accuracy: 0.416294664144516
#     precision: 0.41425442695617676
#     f1_score: 0.39079248905181885
#     recall: 0.416294664144516

# %%
experiment = MixTrainMixTest(
    dataset_name="BloodMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/MixTrainMixTest_BloodMNIST.json
# Experiment Summary: Classifier trained and tested on mixed original and generated data
# Dataset: BloodMNIST
# Test Results:
#     loss: 0.19610860089551352
#     accuracy: 0.9462890625
#     precision: 0.9489606022834778
#     f1_score: 0.9469527006149292
#     recall: 0.9462890625

# %%
experiment = MixTrainMixTest(
    dataset_name="DermaMNIST",
    config=experiments_config
)

experiment.run()
# Out:
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# Saved results to: results/MixTrainMixTest_DermaMNIST.json
# Experiment Summary: Classifier trained and tested on mixed original and generated data
# Dataset: DermaMNIST
# Test Results:
#     loss: 1.8988478992666518
#     accuracy: 0.5535714626312256
#     precision: 0.5720462799072266
#     f1_score: 0.5603761672973633
#     recall: 0.5535714626312256

# %% [markdown]
# ## Porównanie wyników eksperymentów

# %%
plot_experiment('OriginalTrainFakeTest')

# %% [markdown]
# W przypadku, gdy zbiory treningowy i walidacyjny były oryginalne, a zbiór testowy wygenerowany, klasyfikator osiągał na nim znacząco gorsze wyniki niż na pozostałych zbiorach. W przypadku zbioru DermaMNIST, model zbytnio dopasował się do danych treningowych. Dla zbioru BloodMNIST wyniki walidacyje i treningowe były zbliżone.

# %%
plot_experiment('FakeTrainOriginalTest')

# %% [markdown]
# Gdy klasyfikator był uczony i walidowany na danych syntetycznych a testowany na danych oryginalnych, osiągnał lepsze wyniki niż w poprzednim eksperymencie. Dla zbioru BloodMNIST wszystkie metryki były zbliżone, w przypadku DermaMNIST ponownie model przeuczył się.

# %%
plot_experiment('MixTrainMixTest')

# %% [markdown]
# Gdy klasyfikator był uczony na zbiorach wymieszanych w proporcjach 50/50, metryki walidacyjne i testowe były zbliżone do siebie. Ponownie doszło do przeuczenia modelu na datasecie DermaMNIST. Warto jednak zauważyć, że metryki testowe były najlepsze właśnie w tym eksperymencie dla obu zbiorów danych.

# %% [markdown]
# ## Podsumowanie
#
# Generowanie syntetycznych obrazów w celu zwiększenia datasetu, stanowi ciekawy kierunek rozwoju AI. Najciekawsze są wyniki drugiego eksperymentu, w którym użyto do uczenia wyłączenie wygenerowanych danych i przeprowadzono testy na oryginalnym zbiorze. Wyniki były nieznacznie gorsze na zbiorze testowym niż walidacyjnym. Klasy w zbiorach danych były nierównomiernie rozłożone i zastosowany sposób rozwiązania tego problemu (oversampling klas mnieszościowych i undersampling większościowych do zrównania liczności klas) mógł nie być najlepszym. Lepszym rozwiązaniem wydaje się oversampling do liczności najliczniejszej klasy, ale porzucono ten pomysł ze względu na ograniczenia czasowe w trenowaniu modeli i następnie generowaniu zdjęć.
